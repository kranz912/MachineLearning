# %% [markdown]
# # Exploring Iowa House Prices
#
# This notebook is a simple Exploratory Data Analysis of iowa house prices
#
# Dataset  https://www.kaggle.com/nickptaylor/iowa-house-prices/

# %% [markdown]
# ## Data exploration and Cleaning

# %%
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style="ticks",color_codes=True)

# %% [markdown]
# Reading the file from the directory and initializing it to a pandas dataframe object. In exploring we will use the train.csv

# %%
iowa_file_path ='dataset/datasets_13812_18623_train.csv'

# %%
housing_data = pd.read_csv(iowa_file_path)

# %% [markdown]
# Checking what are the available features for data exploration

# %%
housing_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# Checking the dimensions of the data, as you can see we have 1460 rows and 81 columns

# %%
housing_data.shape
# Out:
# (1460, 81)

# %% [markdown]
# Exploring what the data looks like. As you can see we have already missing values/ NaN

# %%
housing_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Counting Missing Data for each features.

# %%
housing_data.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %% [markdown]
# Select Features for exploration. I have selected the features that interest me the most.

# %%
feature_names = ['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd','SalePrice']

# %%
#Creating a separate dataframe with the selected features
housing_data_cleaned =  housing_data[feature_names]

# %%
housing_data_cleaned.head()
# Out:
#    LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 0     8450       2003       856       854         2             3
# 1     9600       1976      1262         0         2             3
# 2    11250       2001       920       866         2             3
# 3     9550       1915       961       756         1             3
# 4    14260       2000      1145      1053         2             4
#
#    TotRmsAbvGrd  SalePrice
# 0             8     208500
# 1             6     181500
# 2             6     223500
# 3             7     140000
# 4             9     250000

# %% [markdown]
# Checking for missing values. No missing values was found and can proceed with visualization

# %%
housing_data_cleaned.isna().sum()
# Out:
# LotArea         0
# YearBuilt       0
# 1stFlrSF        0
# 2ndFlrSF        0
# FullBath        0
# BedroomAbvGr    0
# TotRmsAbvGrd    0
# SalePrice       0
# dtype: int64

# %%
housing_data_cleaned.describe()
# Out:
#              LotArea    YearBuilt     1stFlrSF     2ndFlrSF     FullBath  \
# count    1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    10516.828082  1971.267808  1162.626712   346.992466     1.565068
# std      9981.264932    30.202904   386.587738   436.528436     0.550916
# min      1300.000000  1872.000000   334.000000     0.000000     0.000000
# 25%      7553.500000  1954.000000   882.000000     0.000000     1.000000
# 50%      9478.500000  1973.000000  1087.000000     0.000000     2.000000
# 75%     11601.500000  2000.000000  1391.250000   728.000000     2.000000
# max    215245.000000  2010.000000  4692.000000  2065.000000     3.000000
#
#        BedroomAbvGr  TotRmsAbvGrd      SalePrice
# count   1460.000000   1460.000000    1460.000000
# mean       2.866438      6.517808  180921.195890
# std        0.815778      1.625393   79442.502883
# min        0.000000      2.000000   34900.000000
# 25%        2.000000      5.000000  129975.000000
# ...

# %% [markdown]
# ## Data visualization

# %% [markdown]
# Creating a pairplot to see the relationship between each features

# %%
plt.figure(dpi=120)
sns.pairplot(housing_data_cleaned)
plt.show()

# %% [markdown]
#  ### Exploring the distribution of each variables

# %% [markdown]
# #### Sale price distribution
# As you can see majority of the sale prices are around 100k-200k

# %%
plt.figure(dpi=120)
sns.distplot(housing_data_cleaned[['SalePrice']])
plt.show()

# %% [markdown]
# #### Lot area distribution

# %% [markdown]
# Majority of the houses that are being sold has a lot size less that 50,000 sqm

# %%
plt.figure(dpi=120)
sns.distplot(housing_data_cleaned[['LotArea']])
plt.show()

# %% [markdown]
# ### Year built Distribution
# Year built distribution is skewed to the right indicating there are more newer houses are being sold

# %%
plt.figure(dpi=120)
sns.distplot(housing_data_cleaned[['YearBuilt']])
plt.show()

# %% [markdown]
# ### Relationship between Lot area and Price

# %% [markdown]
# With a correlation value of **0.263843** indicates that there is a weak positive correlation between LotArea and SalePrice

# %%
housing_data_cleaned[['LotArea','SalePrice']].corr()
# Out:
#             LotArea  SalePrice
# LotArea    1.000000   0.263843
# SalePrice  0.263843   1.000000

# %%
sns.relplot(x='LotArea',y='SalePrice',hue="YearBuilt",data=housing_data_cleaned)
sns.despine()

# %% [markdown]
# ### Relationship between Year Built and Price
#
# With a corralation value of **0.522897** it indicates that there is a strong correlation between Year Built and Price

# %%
housing_data_cleaned[['YearBuilt','SalePrice']].corr()
# Out:
#            YearBuilt  SalePrice
# YearBuilt   1.000000   0.522897
# SalePrice   0.522897   1.000000

# %%
sns.relplot(x='YearBuilt',y='SalePrice',hue='YearBuilt',data=housing_data_cleaned)
plt.show()

# %%
sns.regplot(x='YearBuilt',y='SalePrice',data=housing_data_cleaned)
sns.despine()

# %% [markdown]
# ## Predicting Prices base on features

# %% [markdown]
# Importing sklearn packages

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# %% [markdown]
# Split the dataframe into training and test

# %%
train_data = housing_data_cleaned
feature_names = ['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']
target = ['SalePrice']

X = train_data[feature_names]
y = train_data[target]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

# %% [markdown]
# Finding the best max leaf node for training

# %%
from sklearn.metrics import mean_absolute_error


def get_mae(max_leaf_nodes, train_X, val_X, train_y,val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X,train_y)
    pred_val = model.predict(val_X)
    return mean_absolute_error(val_y,pred_val)
    

mae = 10**100
for max_leaf_nodes in [5,50,500,500]:
    current_mae = get_mae(max_leaf_nodes,train_X,val_X,train_y,val_y)
    print("Leaf Node",max_leaf_nodes,"MAE:",current_mae)
    if(mae>current_mae):
        mae = current_mae
        best_leaf_node = max_leaf_nodes

print(best_leaf_node)
# Out:
# Leaf Node 5 MAE: 35044.51299744237
# Leaf Node 50 MAE: 27405.930473214907
# Leaf Node 500 MAE: 29454.18598068598
# Leaf Node 500 MAE: 29454.18598068598
# 50

# %% [markdown]
# Training the model

# %%
regressor = DecisionTreeRegressor(max_leaf_nodes=best_leaf_node,random_state=1)
regressor.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=50, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=1, splitter='best')

# %% [markdown]
# Predict prices from the test.csv dataset

# %%
test_file_path ='dataset/datasets_13812_18623_test.csv'
test_data = pd.read_csv(test_file_path)
test_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
test_data = test_data[feature_names]
regressor.predict(test_data)
# Out:
# array([129504.01020408, 160912.26086957, 175844.32      , ...,
#        160912.26086957, 142034.21052632, 238246.5       ])
